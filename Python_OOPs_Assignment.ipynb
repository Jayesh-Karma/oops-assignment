# %% [markdown]
# # **Python OOPs Assignment**
#
# 1. What is Object Oriented Programming(OOP) ?
#   - OOP is the fundamental concept in python which empower developers to build maintanable, reusable, modular and scalable application.
#   - OOP is a way to organize code by bundling data and methods that work on that data into a self contained containers called Objects, here object refers to the real world entities and there data is like information of that real world entity and there methods are same as there behaviour.
#   - In OOP we map real world entities, there data and behavior to a object in programming thats why this approach is called as Object Oriented Programming.
#
# 2. What is a class in OOP?
#   - Classes are one of the main part of OOPs, and they are work as a blueprint for defining objects. Classes work as a template for creating object.
#   - Classes contains data as attributes and  there methods (functions) together making it easier to manage and use this classes to define different objects.
#   - In Python a class is defined using "class" keyword.
#
# 3. What is an object in OOP?
#   - Its the basic unit OOPs and represents the real world entities in programming. An Object is an instance of a class. When a class is defined its just a blueprint and no memory allocated at that time but when a object is defined using a class then the actual memory is allocated. An Object has an identity, state, and behavior. Each object contains data and methods to manipulate that data.
#
# 4. What is the difference between abstraction and encapsulation?
#   - Abstraction and encapsulation both are the fundamental pillars of OOPs but they both have a very different meaning.
#   - Abstraction refers to providing only essential information about the data to the outside world, hiding the internal implementation. For example, just like we are using laptops or systems so we know which function, key, click will what work, but we dont know how they are internally working correctly. Thats the abstractions
#   - Whereas Encapsulation means, encapsulating or wrapping up the data and the methods into a single unit tightly so that the data and the methods are hidden from the other class and can be accessed only through any member function of their class in which they are declared. The data in the class is controlled by access specifiers and hidden from other classes thats why it is also known as data hiding.
#
# 5. What are dunder methods in Python?
#   - Dunder method also known as Magic Methods are the methods which are defined by build in classes and commonly used for operator overloading.
#   - Dunder means "D-under" which stands for doublt-underscore.
#   - Some examples of dunder methods are: __new__, __init__, __str__ this all are dunders methods are defined by build in classes.
#
# 6. Explain the concept of inheritance in OOP?
#  - In OOP, Inheritance is an important pillar. The capability of a class to derive properties and characterisitcs from another class is called Inheritance. Its just like inheriting data and there methods from a class into an another class, here from which we are inheriting is called as Parent class or base class, and the class in which we are inheriting is called as Child and derived class.
# - It improves the code reusability, maintainability and modularity.
#
# 7. What is Polymorphism in OOP?
#   - Polymorphism is one of the important pillar OOP, Polymorphism stands for, Poly means many and morphism means forms, so polymorphism means many forms.
#   - It refers to the ability of an entity or object to perform different action based on the classes.
#   - It allows same method to work differently depending upon the object it is working with.
#
# 8. How is encapsulation achieved in Python?
#   - In Python, Encapsulation is achieved using classes, we wrap data and methods into single unit by defining classes, and control the visibility of methods and attributes using access modifiers available in python.
#
# 9. What is a constructor in Python?
#   - A Constructor in python is a special method which is used to intialize the initial state of an object. It is automatically called when an object is created from a class, ensuring the object starts in a valid state with its attributes assigned appropriate initial values.
#   - In python the constructor is implemented using __init__() method, its primary purpose is to define and assign values to the instance variables.
#
# 10. What are claass and static method in Python?
#   - This both are build in functions in python, The classmethod is used for transforming a normal regular method into a class method. When a method is defined using using @classmethod decorator, the method is bound to the  class itself. A the result the method receives cls as its first argument instead of self, and can be directly called on the class name itself rather than the instance of a class.
#   - ```
#     class Example:
#           @classmethod
#           def class_method(cls, *args):
#                 #body of a class method
#
#     ```
#   - Where as static method does not receive any implicit first argument. It is also bound to the class not to the object of the class. This method can not access or modify the state of the class.
#
# 11. What is method overloading in Python?
#   - Method overloading is used to achieve compile time Polymorphism, but python doesn't support method overloading directly because python is dynamically typed, it checks types at runtime, not compile time. When we define multiple methods with same name, Python simple overwrites the previous definition and keeps only the last one. Altough similar behavior can be achieved using default or variable arguments.
#
# 12. What is method overriding in OOP?
#   - Method overriding is used to achieve runtime polymorphism, It means the behavior or actual implementation of a method is decided at a runtime, based on the object calling it. In python this is achieved using method overriding where there is two classes, parent and child, child class is inheriting methods and attributes from the parent class, but that child class provides its own version of a method, which is already defined in the parent class. Which results when we call that method from the child class object it behaves differently whereas when we call that method from the parent class object then it behaves differently. So that behavior of a method is decided at runtime which is achieved via method overriding to implement runtime polymorphism.
#
# 13. What is a property decorator in Python?
#   - The Property decorator is a decorator in python, it is a build in function that allows a method to be accessed and manipulated as a class attribute.
#   - It allows you to control how attributes are accessed and modified, hiding the internal implementation details from external code.
#
# 14. Why is Polymorphism important in OOP?
#   - Polymorphism is one of the important pillar of OOPs concept and it is very important for developers to write more usable and scallable code, makes code more flexible & reusable as well.
#   - Polymorphism allows objects to respond differently to the same method call depending upon the object it is working with.
#
# 15. What is an abstract class in Python?
#   - Abstract class in python is a class which serves as a blueprint for other classes, defining a common interface or structure that all the derived classes must follow. It cannot be instantiated directly with objects because it contains one or more abstract methods that lack implementation.
#
# 16. What are the advantages of OOP?
#   - There are various advantages of OOPs some of them are modularity, reusability, and maintainabilty through concepts like encapsulation, inheritance, leading to easier debugging, better organization, enhanced security and improved scalability.
#
# 17. What is the difference between a class variable and an instance variable?
#   - The difference between the class variable and instance variable is, the class variable is shared across all the instances of the class, whereas object variables are unique to each individual object.
#   - Class vaiables are defined directly withint the class body, outside of any methods and the instance variables are defined inside the constructor __init__() method.
#
# 18. What is multiple inheritance in Python?
#   - It is a type of Inheritance in Python which allows a child class to inherit properties from more then one parent class. This enables the child class to combine functinalities from multiple sources.
#   - Example
#     ```
#       class Father:
#           def skill1(self):
#               print("Gardening and programming")
#
#       class Mother:
#           def skill2(self):
#               print("Cooking")
#
#       class Son(Father, Mother):
#           pass
#
#       son = Son()
#       son.skill1()  # Gardening and programming
#       son.skill2()  # Cooking
#     ```
#
# 19. Explain the purpose of ``__str__`` and ``__repr__`` methods in python?
#   - The ``__str__ and __repr__ `` both are special dunder methods are in python. This methods provide string representations of an object, but they server different purposes.
#   - ``__str__`` method is used to provide a concise, user-friendly and easy to read string that is suitable for display, logging. It is called by print(obj) when we try to print the object or str(obj)
#   - ``__repr__`` method is used to provide a clear, information representatin of the object's state, primarily for debugging, loggin, diagnotic information. Called by repr(obj) function
#
# 20. What is the significance of the `super()` function in python?
#   - The super() method is a buld in function used in a subclass to access the methods and properties of its parent class.
#   - it returns a proxy object of the parent class which allows us to reuse inherited logic.
#
# 21. What is the significance of the __del__ method in Python?
#   - `__del__` method in python is a dunder method that is called by the garbage collector just before an object is destroyed and its memory is reclaimed.
#   - It acts as destructor for a class, providing a mechanism for performing cleanup actions when an object is no longer in use.
#
# 22. What is the difference between @staticmethod and @classmethod in Python?
#   - Both @staticmethod and @classmethod are decorators used to define methods within a class that can be called without creating an instance of the class.
#   - The fundamental difference between them is their first argument and there access capabilities.
#   - @staticmethod is a regular function that is bounded to the class itself instead of instance object, but it does not take any first argument and not able to modify or update anything in the class state or the instance state.
#   - whereas @classmethod is also a function which is bounded to the class itself instead of instance object but it takes first argument as `cls` which refers to the class object itself. And it is able to access, modify the class level data because it has a reference to it.
#
# 23. How does polymorphism work in Python with inheritance?
#   - In python, polymorphism will not work without inheritance. Polymorphism primarily works with Inheritance by method overriding, where a child class redefines a method that is already present in its parent class.
#   - This allows object of different classes that have the same parent class to respond differently to the same method call by overriding the definition defined in the parent class.
#
# 24. What is method chaining in Python OOP?
#   - In OOPs, method chaining is a technique for calling multiple methods sequentially on the same object in a single, continuous line of code. This is a design pattern which makes the code more concise, readable, and avoids the need for temporary variables to store intermediate results.
#
# 25. What is the purpose of the `__call__` method in Python?
#   - `__call__` method is a special dunder method that enables an instance of a clas to be used and invoked as if it were a regular function.
#   - This makes the object callable and allows for flexible, function like behaviour while maintaining object oriented capabilities and state.

# %%
#coding practical questions

# 1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
# that overrides the speak() method to print "Bark!".
class Animal:
  def speak(self):
    print("Hello Everyone!")

class Dog(Animal):
  def speak(self):
    print("Bark!")

dog = Dog()
dog.speak()
# Out:
# Bark!

# %%
# 2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
# from it and implement the area() method in both.

from abc import ABC, abstractmethod

class Shape(ABC):
  @abstractmethod
  def area(self):
    pass

class Circle(Shape):
  def __init__(self, radius):
    self.radius = radius

  def area(self):
    return 3.14 * self.radius * self.radius

class Rectangle(Shape):
  def __init__(self, length, breadth):
    self.length = length
    self.breadth = breadth

  def area(self):
    return self.length * self.breadth


circle = Circle(5)
areaCircle = circle.area()

rectangle = Rectangle(5, 5)
areaRect = rectangle.area()

print("Area of Circle is: ", areaCircle)
print("Area of Rectangle is: ", areaRect)
# Out:
# Area of Circle is:  78.5
# Area of Rectangle is:  25

# %%
# 3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
# and further derive a class ElectricCar that adds a battery attribute.
class Vehicle:
  def __init__(self, vehicle_type):
    self.type = vehicle_type

  def display(self):
    print("Vehicle Type is: ", self.type)


class Car(Vehicle):
  def __init__(self, vehicle_type, brand):
      super().__init__(vehicle_type)
      self.brand  = brand

  def display(self):
      print(f"This is a {self.type} of brand {self.brand}")

class ElectricCar(Car):
  def __init__(self, vehicle_type, brand, battery):
    super().__init__(vehicle_type, brand)
    self.battery = battery

  def display(self):
    print(f"This is an {self.type}, of brand {self.brand} with a batter of {self.battery}")



car = Car("Petrol Car", "Jeep")
car.display()

ev = ElectricCar("Electric car", "Tesla", "100vh")
ev.display()
# Out:
# This is a Petrol Car of brand Jeep
# This is an Electric car, of brand Tesla with a batter of 100vh

# %%
# 4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
# Sparrow and Penguin that override the fly() method.
class Bird:
  def fly(self):
    print("Flying....")

class Sparrow(Bird):
  def fly(self):
    print("Sparrow Flying...")

class Penguin(Bird):
  def fly(self):
    print("Penguin can not fly")

bird = Bird()
bird.fly()


sparrow = Sparrow()
sparrow.fly()

penguin = Penguin()
penguin.fly()
# Out:
# Flying....
# Sparrow Flying...
# Penguin can not fly

# %%
# 5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
# balance and methods to deposit, withdraw, and check balance

class BankAccount:
  def __init__(self, balance):
    self.__balance = balance

  def deposit(self, amount):
    if(amount > 0):
      print(f"Depostied {amount} in your account.")
      self.__balance += amount
    else:
      print("Invalid amount!")

  def withdraw(self, amount):
    if(amount < self.__balance and amount > 0):
      print(f"Withdrawing {amount} from your account")
      self.__balance -= amount
    else:
      print("Not sufficient balance")

  def checkbalance(self):
    print("Remaining balance: ", self.__balance)


bankAcc = BankAccount(1000)
bankAcc.deposit(5000)
bankAcc.checkbalance()
bankAcc.withdraw(500)
bankAcc.checkbalance()
# Out:
# Depostied 5000 in your account.
# Remaining balance:  6000
# Withdrawing 500 from your account
# Remaining balance:  5500

# %%
# 6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
# and Piano that implement their own version of play().

class Instrument:
  def play(self):
    print("Playing Instrument")

class Guitar(Instrument):
  def play(self):
    print("Playning Guitar")

class Piano(Instrument):
  def play(self):
    print("Playing Piano")


piano = Piano()
piano.play()

guitar = Guitar()
guitar.play()


instrument = Instrument()
instrument.play()
# Out:
# Playing Piano
# Playning Guitar
# Playing Instrument

# %%
# 7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static
# method subtract_numbers() to subtract two numbers.

class MathOperations:
  @classmethod
  def add_numbers(cla, a, b):
    return a+b

  @staticmethod
  def subtract_numbers(a, b):
    return a-b


print("Addition of 5 and 45 is ", MathOperations.add_numbers(5, 45))
print("Substraction of 45 and 5 is ", MathOperations.subtract_numbers(45, 5))
# Out:
# Addition of 5 + 45 is  50
# Substraction of 45 and 5 is  40

# %%
# 8. Implement a class Person with a class method to count the total number of persons created.
class Person:
  totalPersons = 0

  def __init__(self):
      Person.totalPersons += 1


  @classmethod
  def CountPersons(cls):{
      print("Total Number of Persons created using this class are:", cls.totalPersons)
  }

person1 = Person()
person2 = Person()
person3 = Person()

Person.CountPersons()
# Out:
# Total Number of Persons created using this class are: 3

# %%
# 9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the
# fraction as "numerator/denominator".
class Fraction:
  def __init__(self, numerator, denominator):
    self.numerator = numerator
    self.denominator = denominator

  def __str__(self):
    return f"The given fraction is: {self.numerator}/{self.denominator}"


fraction = Fraction(5, 6)
print(fraction)

fraction2 = Fraction(50, 10)
print(fraction2)
# Out:
# The given fraction is: 5/6
# The given fraction is: 50/10

# %%
# 10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
# vectors.

class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def display(self):
        print(f"Vector({self.x}, {self.y})")


v1 = Vector(2, 3)
v2 = Vector(4, 5)

v3 = v1 + v2

v3.display()
# Out:
# Vector(6, 8)

# %%
# 11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
# {name} and I am {age} years old."
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def greet(self):
    print(f"Hello, my name is {self.name} and I am {self.age} years old.")


person = Person("Jayesh", 22)
person.greet()

person2 = Person("Ajay Kumar Gupta", 28)
person2.greet()
# Out:
# Hello, my name is Jayesh and I am 22 years old.
# Hello, my name is Ajay Kumar Gupta and I am 28 years old.

# %%
# 12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute
# the average of the grades.
class Student:
  def __init__(self, name, grades):
    self.name = name
    self.grades = grades

  def average_grade(self):
    sum = 0
    totalSub = len(self.grades)
    for i in self.grades:
      sum += i

    return sum/totalSub

student1 = Student("Jayesh", [100,  50, 80, 90, 72])
print(f"Average grade of student {student1.name} is {student1.average_grade()}")


student2 = Student("Ajay Sir", [100, 99, 99, 99, 95])
print(f"Average grade of {student2.name} is {student2.average_grade()}")
# Out:
# Average grade of student Jayesh is 78.4
# Average grade of Ajay Sir is 98.4

# %%
# 13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
# area.
class Rectangle:
  def set_dimensions(self, length, breadth):
    self.length = length
    self.breadth = breadth

  def area(self):
    return f"Area of this rectangle is: {self.length * self.breadth}"

rectangle1 = Rectangle()
rectangle1.set_dimensions(5, 10)
print(rectangle1.area())

rectangle1.set_dimensions(10, 30)
print(rectangle1.area())
# Out:
# Area of this rectangle is: 50
# Area of this rectangle is: 300

# %%
# 14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
# and hourly rate. Create a derived class Manager that adds a bonus to the salary.
class Employee:
  def __init__(self, hours_worked, hourly_rate):
    self.hours_worked = hours_worked
    self.hourly_rate = hourly_rate

  def calculate_salary(self):
    return self.hours_worked * self.hourly_rate

class Manager(Employee):
  def __init__(self, hours_worked, hourly_rate, bonus):
    super().__init__(hours_worked, hourly_rate)
    self.bonus = bonus

  def calculate_salary(self):
    return super().calculate_salary() + self.bonus


employee = Employee(9, 700)
print(f"Employee Salary: ", employee.calculate_salary())

employee2 = Manager(9, 700, 1000)
print(f"Manager with bonus: {employee2.calculate_salary()}")
# Out:
# Employee Salary:  6300
# Manager with bonus: 7300

# %%
# 15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
# calculates the total price of the product.
class Product:
  def __init__(self, name, price, quantity):
    self.name = name
    self.price = price
    self.quantity = quantity

  def total_price(self):
    return self.price * self.quantity


product1 = Product("Rolex Watch", 5000000, 2)
print(f"Total price of {product1.name} is {product1.total_price()}")
# Out:
# Total price of Rolex Watch is 10000000

# %%
# 16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
# implement the sound() method.
from abc import ABC, abstractmethod

class Animal(ABC):
  @abstractmethod
  def sound(self):
    pass

class Cow(Animal):
  def sound(self):
    print("Cow says moooo!!!")

class Sheep(Animal):
  def sound(self):
    print("Sheep says meeee!!")

cow = Cow()
cow.sound()

sheep = Sheep()
sheep.sound()
# Out:
# Cow says moooo!!!
# Sheep says meeee!!

# %%
# 17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
# returns a formatted string with the book's details.

class Book:
  def __init__(self, title, author, year_published):
    self.title = title
    self.author = author
    self.year_published = year_published

  def get_book_info(self):
    return f"The Title of the book is {self.title} published in {self.year_published}, and its author name is {self.author}"

book1 = Book("Atomic Habits", "James clear", 2018)
print(book1.get_book_info())
# Out:
# The Title of the book is Atomic Habits published in 2018, and its author name is James clear

# %%
# 18. Create a class House with attributes address and price. Create a derived class Mansion that adds an
# attribute number_of_rooms
class House:
  def __init__(self, address, price):
    self.address = address
    self.price = price
  def display(self):
    print(f"This House is located at {self.address} as a price of {self.price}")


class Mansion(House):
  def __init__(self, address, price, number_of_rooms):
    super().__init__(address, price)
    self.number_of_rooms = number_of_rooms

  def details(self):
    print(f"Mansion located in {self.address} and available for a price of {self.price} and has total {self.number_of_rooms} rooms.")

house = House("Indore", 500000)
house.display()
mansion = Mansion("Mumbai", 5500000, 5)
mansion.display()
# Out:
# This House is located at Indore as a price of 500000
# This House is located at Mumbai as a price of 5500000
